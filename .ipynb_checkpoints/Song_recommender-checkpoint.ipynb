# %%
import pandas as pd
from config import *
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                           client_secret=client_secret_id))

# %%
data = pd.read_csv("all_songs.csv")

# %%
data.head()
# Out:
#              Title                       Artist  danceability  energy  key  \
# 0        Kill Bill                          SZA         0.644   0.735    8
# 1       Last Night                Morgan Wallen         0.517   0.675    6
# 2          Flowers                  Miley Cyrus         0.707   0.681    0
# 3   Princess Diana      Ice Spice & Nicki Minaj         0.898   0.676    9
# 4  Ella Baila Sola  Eslabon Armado X Peso Pluma         0.668   0.758    5
#
#    loudness  mode  speechiness  acousticness  instrumentalness  ...    tempo  \
# 0    -5.747     1       0.0391        0.0521          0.144000  ...   88.980
# 1    -5.382     1       0.0357        0.4590          0.000000  ...  203.853
# 2    -4.325     1       0.0668        0.0632          0.000005  ...  117.999
# 3    -5.196     1       0.1870        0.1400          0.000000  ...  147.991
# 4    -5.176     0       0.0332        0.4830          0.000019  ...  147.989
#
#              type                      id  \
# 0  audio_features  1Qrg8KqiBpW07V7PNxwwwL
# 1  audio_features  59uQI0PADDKeE6UZDTJEe8
# 2  audio_features  4DHcnVTT87F0zZhRPYmZ3B
# 3  audio_features  0ZxhtATQ0a6EvQNZ0z6NKV
# 4  audio_features  3dnP0JxCgygwQH9Gm7q7nb
#
#                                     uri  \
# 0  spotify:track:1Qrg8KqiBpW07V7PNxwwwL
# 1  spotify:track:59uQI0PADDKeE6UZDTJEe8
# 2  spotify:track:4DHcnVTT87F0zZhRPYmZ3B
# 3  spotify:track:0ZxhtATQ0a6EvQNZ0z6NKV
# 4  spotify:track:3dnP0JxCgygwQH9Gm7q7nb
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1Qrg8KqiBpW0...
# 1  https://api.spotify.com/v1/tracks/59uQI0PADDKe...
# 2  https://api.spotify.com/v1/tracks/4DHcnVTT87F0...
# 3  https://api.spotify.com/v1/tracks/0ZxhtATQ0a6E...
# 4  https://api.spotify.com/v1/tracks/3dnP0JxCgygw...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1Qrg...      153947
# 1  https://api.spotify.com/v1/audio-analysis/59uQ...      163855
# 2  https://api.spotify.com/v1/audio-analysis/4DHc...      200455
# 3  https://api.spotify.com/v1/audio-analysis/0Zxh...      172125
# 4  https://api.spotify.com/v1/audio-analysis/3dnP...      165671
#
#   time_signature  hot  cluster
# 0              4  Yes        1
# 1              4  Yes        4
# 2              4  Yes        5
# 3              4  Yes       11
# 4              3  Yes        5
#
# [5 rows x 22 columns]

# %%
data.columns
# Out:
# Index(['Title', 'Artist', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature', 'hot', 'cluster'],
#       dtype='object')

# %%
def song_recommendation():
    artist = input("Please enter the artist: ")
    title = input("Please enter the song title: ")
    try: 
        string = "tracks: " + title + "artist: " + artist
        song=sp.search(q=string,limit=5)
        song_id = [song['tracks']['items'][0]['id']]
        artist_name = song['tracks']['items'][0]['album']['artists'][0]['name']
        song_name = song['tracks']['items'][0]['name']
        print(song_name)
        print(artist_name)
    except:
        print("Song not found!")
  
    while True:
        try:
            choice = int(input("Please type a number to choose the version you want: "))
        except ValueError:
            print("Sorry, I didn't understand that.")
            continue
            
        if (choice <= 0) or (choice>len(song_id)):
            print("Sorry, your response must be within the 0 and ", len(song_id)+1)
            continue
        else:
            break
    if song_id[choice-1] in list(data['id']):
        print("Song exists!")
        cluster = list(data['cluster'][data['Title']==title])[0]
        #print(cluster)
        if list(data['hot'][data['id']==song_id[choice-1]])[0] == 'Yes':
            title_lst = pd.DataFrame(data[['Title','Artist','id']][(data['hot']=='Yes') & (data['cluster']==cluster)].sample(5))
            title_lst['id']=title_lst['id'].apply(lambda x: "https://open.spotify.com/track/"+x)
            pd.set_option('display.width', 2000)
        else: 
            title_lst = pd.DataFrame(data[['Title','Artist','id']][(data['hot']=='No') & (data['cluster']==cluster)].sample(5))
            title_lst['id']=title_lst['id'].apply(lambda x: "https://open.spotify.com/track/"+x)
            pd.set_option('display.width', 2000)
        print("Thanks for using our song recommender!")
        return title_lst
    else: 
        print("Sorry! Song not found in our system! We will update our system asap.")

# %%
song_recommendation()
# Out:
# Please enter the artist: SZA
# Please enter the song title: Kill Bill
# Kill Bill
# SZA
# Please type a number to choose the version you want: 0
# Sorry, your response must be within the 0 and  2
# Please type a number to choose the version you want: "S
# Sorry, I didn't understand that.
# Please type a number to choose the version you want: 1
# Song exists!
# Thanks for using our song recommender!
#                   Title         Artist                                                 id
# 0             Kill Bill            SZA  https://open.spotify.com/track/1Qrg8KqiBpW07V7...
# 48   Heart Like A Truck  Lainey Wilson  https://open.spotify.com/track/5ZCjp56T8J6d7am...
# 95          Memory Lane   Old Dominion  https://open.spotify.com/track/5kB6WithhB8Iv08...
# 26  Under The Influence    Chris Brown  https://open.spotify.com/track/5IgjP7X4th6nMND...
# 52          Bloody Mary      Lady Gaga  https://open.spotify.com/track/11BKm0j4eYoCPPp...

# %%
song_recommendation()
# Out:
# Please enter the artist: Queen
# Please enter the song title: Bohemian Rhapsody
# Bohemian Rhapsody
# Queen
# Please type a number to choose the version you want: 1
# Song exists!
# Thanks for using our song recommender!
#                          Title                         Artist                                                 id
# 2313  Make It Easy on Yourself            The Walker Brothers  https://open.spotify.com/track/5DNmWyeY9sildee...
# 420                   Fast Car                  Tracy Chapman  https://open.spotify.com/track/2M9ro2krNb7nr7H...
# 2511                     Omaha                     Moby Grape  https://open.spotify.com/track/2Uwjr7EnHRXMgmL...
# 1563              I'm Eighteen                   Alice Cooper  https://open.spotify.com/track/3YU9X8ryOR20beT...
# 1823    All Tomorrow's Parties  The Velvet Underground & Nico  https://open.spotify.com/track/1mL6q0gbifm2dBT...
